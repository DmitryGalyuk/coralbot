# %%
from pandas import *

df_raw: DataFrame = read_excel("sampleCur.xlsx", skiprows=6, na_values=[' '])
# df_raw = df_raw.dropna()
df_raw = df_raw[to_numeric(df_raw['#'], errors='coerce').notnull()]
df_raw
# Out:
#        # Number of Generations  Club Member (First name/Last name)  \
# 0      1                   .0                            6111685.0
# 1      2                   .1                            6190205.0
# 2      3                   .2                            6202838.0
# 3      4                   .2                            6866923.0
# 4      5                   .3                            6959087.0
# ..   ...                   ...                                 ...
# 723  724                   .1                            7625037.0
# 724  725                   .1                            7634313.0
# 725  726                   .1                            7659464.0
# 726  727                   .1                            7742962.0
# 727  728                   .1                            7821743.0
#
#                Unnamed: 3 CNV (Cumulated Network Volume) Rank   P  \
# 0             Галюк Елена                          > 500    E NaN
# 1           Галюк Дмитрий                          > 500    D NaN
# 2     Tabolich Anastasiya                          > 500   PM NaN
# 3    Фалавандишвили Натия                          > 500   PM NaN
# 4        Мурванидзе Луиза                          > 500   PM NaN
# ..                    ...                            ...  ...  ..
# 723       Зоидзе Светлана                          273.4  NaN NaN
# 724       Rodionova Elena                             69  NaN NaN
# 725        Каитамба Раули                           82.2    M NaN
# 726         Павлова Ирина                            500   PM NaN
# 727       Lohvynenko Olha                            NaN  NaN NaN
#
#      PV (Personal Volume)    PVG MCR (Maximum Confirmed Rank)  \
# 0                   100.0  230.0                          E/1
# 1                     NaN    NaN                        SD/28
# 2                     NaN    NaN                          NaN
# 3                     NaN    7.0                         D/28
# 4                     7.0    NaN                          NaN
# ..                    ...    ...                          ...
# 723                   NaN    NaN                          NaN
# 724                   NaN    NaN                          NaN
# 725                   NaN    NaN                          NaN
# 726                   NaN    NaN                          D/2
# 727                  68.0    NaN                          NaN
#
#      Number of months with zero Volume Points accrued Club Member Status
# 0                                                 NaN                NaN
# 1                                                 1.0                  m
# 2                                                12.0                  m
# 3                                                 7.0                  m
# 4                                                 NaN                  m
# ..                                                ...                ...
# 723                                               4.0                  m
# 724                                               2.0                  m
# 725                                               1.0                  m
# 726                                               2.0                  m
# 727                                               NaN                  m
#
# [728 rows x 12 columns]

# %%
excel2Field = {}
excel2Field["#"] = "rownum"
excel2Field["Number of Generations"] = "gen"
excel2Field["Club Member (First name/Last name)"] = "Id"
excel2Field["Unnamed: 3"] = "Name"
excel2Field["CNV (Cumulated Network Volume)"] = "cnv"
excel2Field["Rank"] = "Rank"
excel2Field["P"] = "Pending"
excel2Field["PV (Personal Volume)"] = "Personal"
excel2Field["PVG"] = "Group"
excel2Field["MCR (Maximum Confirmed Rank)"] = "maxrank"
excel2Field["Number of months with zero Volume Points accrued"] = "zeroMonths"
excel2Field["Club Member Status"] = "status"

df_renamed = df_raw.rename(columns=excel2Field)
df_renamed
# Out:
#     rownum     gen         Id                  Name    cnv Rank  Pending  \
# 0        1     .0   6111685.0           Галюк Елена  > 500    E      NaN
# 1        2     .1   6190205.0         Галюк Дмитрий  > 500    D      NaN
# 2        3     .2   6202838.0   Tabolich Anastasiya  > 500   PM      NaN
# 3        4     .2   6866923.0  Фалавандишвили Натия  > 500   PM      NaN
# 4        5     .3   6959087.0      Мурванидзе Луиза  > 500   PM      NaN
# ..     ...     ...        ...                   ...    ...  ...      ...
# 723    724     .1   7625037.0       Зоидзе Светлана  273.4  NaN      NaN
# 724    725     .1   7634313.0       Rodionova Elena     69  NaN      NaN
# 725    726     .1   7659464.0        Каитамба Раули   82.2    M      NaN
# 726    727     .1   7742962.0         Павлова Ирина    500   PM      NaN
# 727    728     .1   7821743.0       Lohvynenko Olha    NaN  NaN      NaN
#
#      Personal  Group maxrank  zeroMonths status
# 0       100.0  230.0     E/1         NaN    NaN
# 1         NaN    NaN   SD/28         1.0      m
# 2         NaN    NaN     NaN        12.0      m
# 3         NaN    7.0    D/28         7.0      m
# 4         7.0    NaN     NaN         NaN      m
# ..        ...    ...     ...         ...    ...
# 723       NaN    NaN     NaN         4.0      m
# 724       NaN    NaN     NaN         2.0      m
# 725       NaN    NaN     NaN         1.0      m
# 726       NaN    NaN     D/2         2.0      m
# 727      68.0    NaN     NaN         NaN      m
#
# [728 rows x 12 columns]

# %%
df_recast = df_renamed.convert_dtypes(convert_floating=True, convert_integer=True)
df_recast["Personal"].astype(float)
df_recast
# Out:
#      rownum     gen       Id                  Name    cnv  Rank  Pending  \
# 0         1     .0   6111685           Галюк Елена  > 500     E     <NA>
# 1         2     .1   6190205         Галюк Дмитрий  > 500     D     <NA>
# 2         3     .2   6202838   Tabolich Anastasiya  > 500    PM     <NA>
# 3         4     .2   6866923  Фалавандишвили Натия  > 500    PM     <NA>
# 4         5     .3   6959087      Мурванидзе Луиза  > 500    PM     <NA>
# ..      ...     ...      ...                   ...    ...   ...      ...
# 723     724     .1   7625037       Зоидзе Светлана  273.4  <NA>     <NA>
# 724     725     .1   7634313       Rodionova Elena     69  <NA>     <NA>
# 725     726     .1   7659464        Каитамба Раули   82.2     M     <NA>
# 726     727     .1   7742962         Павлова Ирина    500    PM     <NA>
# 727     728     .1   7821743       Lohvynenko Olha    NaN  <NA>     <NA>
#
#      Personal  Group maxrank  zeroMonths status
# 0       100.0  230.0     E/1        <NA>   <NA>
# 1        <NA>   <NA>   SD/28           1      m
# 2        <NA>   <NA>    <NA>          12      m
# 3        <NA>    7.0    D/28           7      m
# 4         7.0   <NA>    <NA>        <NA>      m
# ..        ...    ...     ...         ...    ...
# 723      <NA>   <NA>    <NA>           4      m
# 724      <NA>   <NA>    <NA>           2      m
# 725      <NA>   <NA>    <NA>           1      m
# 726      <NA>   <NA>     D/2           2      m
# 727      68.0   <NA>    <NA>        <NA>      m
#
# [728 rows x 12 columns]

# %%
df_gen = df_recast
df_gen.gen=df_gen.gen.apply(lambda x: int(str(x).split(".")[-1]) )
df_gen
# Out:
#      rownum  gen       Id                  Name    cnv  Rank  Pending  \
# 0         1    0  6111685           Галюк Елена  > 500     E     <NA>
# 1         2    1  6190205         Галюк Дмитрий  > 500     D     <NA>
# 2         3    2  6202838   Tabolich Anastasiya  > 500    PM     <NA>
# 3         4    2  6866923  Фалавандишвили Натия  > 500    PM     <NA>
# 4         5    3  6959087      Мурванидзе Луиза  > 500    PM     <NA>
# ..      ...  ...      ...                   ...    ...   ...      ...
# 723     724    1  7625037       Зоидзе Светлана  273.4  <NA>     <NA>
# 724     725    1  7634313       Rodionova Elena     69  <NA>     <NA>
# 725     726    1  7659464        Каитамба Раули   82.2     M     <NA>
# 726     727    1  7742962         Павлова Ирина    500    PM     <NA>
# 727     728    1  7821743       Lohvynenko Olha    NaN  <NA>     <NA>
#
#      Personal  Group maxrank  zeroMonths status
# 0       100.0  230.0     E/1        <NA>   <NA>
# 1        <NA>   <NA>   SD/28           1      m
# 2        <NA>   <NA>    <NA>          12      m
# 3        <NA>    7.0    D/28           7      m
# 4         7.0   <NA>    <NA>        <NA>      m
# ..        ...    ...     ...         ...    ...
# 723      <NA>   <NA>    <NA>           4      m
# 724      <NA>   <NA>    <NA>           2      m
# 725      <NA>   <NA>    <NA>           1      m
# 726      <NA>   <NA>     D/2           2      m
# 727      68.0   <NA>    <NA>        <NA>      m
#
# [728 rows x 12 columns]

# %%
levelId = {}
def id_gen_2_parent(id, gen) -> int:
    levelId[gen] = id
    return levelId[gen-1] if gen > 0 else -1

if "ParentId" not in df_gen.columns:
    df_gen.insert(loc=3, column="ParentId", value=df_gen.apply(lambda x: id_gen_2_parent(x.Id, x.gen), axis=1))
    df_gen.ParentId = df_gen.ParentId.astype(int)

df_gen
df_gen.dtypes
# Out:
# rownum                 Int64
# gen                    int64
# Id                     Int64
# ParentId               int64
# Name          string[python]
# cnv                   object
# Rank          string[python]
# Pending              Float64
# Personal             Float64
# Group                Float64
# maxrank       string[python]
# zeroMonths             Int64
# status        string[python]
# dtype: object

# %%
members = {}
parents = {}

def calculate_overallstructure_total(id):
    member = members[id]
    member["Overall"] += member["Personal"] or 0
    if id in parents:
        children = [c for c in members.values() if c["ParentId"] == member["Id"]]
        for c in children:
            member["Overall"] += calculate_overallstructure_total(c["Id"])
    return member["Overall"]

df_gen["Overall"] = 0
d = df_gen.to_dict(orient="index")
members = {r["Id"] : r for r in d.values()}
parents = {r["ParentId"] : r["Id"] for r in d.values()}
calculate_overallstructure_total(parents[-1])
memberOverall = {x["Id"]: x["Overall"] for x in members.values()}
df_gen["Overall"] = df_gen["Id"].map(memberOverall)
df_gen.head(50)
# Out:
#     rownum  gen       Id  ParentId                              Name    cnv  \
# 0        1    0  6111685        -1                       Галюк Елена  > 500
# 1        2    1  6190205   6111685                     Галюк Дмитрий  > 500
# 2        3    2  6202838   6190205               Tabolich Anastasiya  > 500
# 3        4    2  6866923   6190205              Фалавандишвили Натия  > 500
# 4        5    3  6959087   6866923                  Мурванидзе Луиза  > 500
# 5        6    4  7309266   6959087                Murvanidze Violeta  135.5
# 6        7    3  7575828   6866923  Фалавандишвили Тинатин Тимуровна     35
# 7        8    2  7688719   6190205                     Konidala Anna  > 500
# 8        9    2  7791032   6190205              Shaposhnikov Mikhail    NaN
# 9       10    2  7805120   6190205            Галюк Елена Николаевна    NaN
# 10      11    2  7834868   6190205              Malyshava Katsiaryna     29
# 11      12    1  6190820   6111685                       Синица Тома  > 500
# 12      13    1  6203900   6111685                        Галюк Варя  > 500
# 13      14    2  6556807   6203900    Шидловская Анджела Григорьевна  > 500
# 14      15    3  6673758   6556807                    Вабищевич Анна  > 500
# 15      16    4  6684011   6673758                    Дедович Тамара  438.5
# 16      17    4  6782839   6673758       Вабищевич Владимир Петрович    221
# 17      18    4  6801396   6673758   Вабищевич Мирослав Владимирович  225.1
# 18      19    4  6842229   6673758     Будник Светлана Александровна  271.4
# 19      20    4  7254343   6673758               Федосенко Екатерина  133.5
# 20      21    3  6679651   6556807                   Нестер Христина  > 500
# 21      22    3  6702054   6556807                  Вечерова Наталья     99
# 22      23    3  6702224   6556807                        Нестер Яна  > 500
# 23      24    2  7187692   6203900   Коровкина Александра Михайловна  464.5
# 24      25    2  7310915   6203900                   Фролова Евгения  > 500
# 25      26    3  7322535   7310915                     Мадатова Дина   69.8
# 26      27    3  7338482   7310915                   Фролова Мелисса  > 500
# 27      28    4  7439339   7338482                    Грищенко Елена     94
# 28      29    4  7449946   7338482                  Назарова Наталия     90
# 29      30    4  7456980   7338482               Kosiakova Ekaterina  438.2
# 30      31    5  7843365   7456980        Шакирьянов Артур Рафикович    NaN
# 31      32    3  7436554   7310915     Терехина Екатерина Максимовна    133
# 32      33    4  7437494   7436554       Акудович Антонина Сергеевна     50
# 33      34    4  7526797   7436554               Mikhailova Nadezhda     71
# 34      35    3  7536391   7310915                   Minjaeva Olesya     24
# 35      36    3  7554677   7310915                   Makeenkova Anna     65
# 36      37    3  7577949   7310915                Astrouskaya Yuliya    168
# 37      38    3  7596790   7310915                     Frolov Dmitry  196.4
# 38      39    3  7833492   7310915                Lyashkevich Sofiya    NaN
# 39      40    3  7864524   7310915                    Rasulova Natia    NaN
# 40      41    1  6204299   6111685                        Галюк Надя  > 500
# 41      42    2  6217050   6204299                Шинкевич Валентина  > 500
# 42      43    3  6218172   6217050                   Шинкевич Андрей  > 500
# 43      44    4  6315386   6218172                   Михайлова Мария  > 500
# 44      45    4  6316880   6218172                      Шинкевич Яна  > 500
# 45      46    4  7049806   6218172         Воронович Юлия Валерьевна  > 500
# 46      47    2  6742267   6204299           Свирид Ирина Михайловна  362.8
# 47      48    2  6827084   6204299                  Станкевич Оксана  467.7
# 48      49    1  6300800   6111685         Баризоне Ольга Алексеевна  > 500
# 49      50    2  6361665   6300800                   Баризоне Серджо  > 500
#
#     Rank  Pending  Personal  Group maxrank  zeroMonths status  Overall
# 0      E     <NA>     100.0  230.0     E/1        <NA>   <NA>  12884.7
# 1      D     <NA>      <NA>   <NA>   SD/28           1      m      7.0
# 2     PM     <NA>      <NA>   <NA>    <NA>          12      m      0.0
# 3     PM     <NA>      <NA>    7.0    D/28           7      m      7.0
# 4     PM     <NA>       7.0   <NA>    <NA>        <NA>      m      7.0
# 5   <NA>     <NA>      <NA>   <NA>    <NA>           3      m      0.0
# 6   <NA>     <NA>      <NA>   <NA>    <NA>           7      m      0.0
# 7     PM     <NA>      <NA>   <NA>     D/4           1      m      0.0
# 8   <NA>     <NA>      <NA>   <NA>    <NA>           2   c/60      0.0
# 9   <NA>     <NA>      <NA>   <NA>    <NA>           1   c/49      0.0
# 10     M     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 11    PM     <NA>      21.5   21.5    D/69        <NA>      m     21.5
# 12     A     <NA>      43.5  102.5     D/3        <NA>   <NA>    234.2
# 13    PM     <NA>      11.0   <NA>    <NA>        <NA>      m     59.0
# 14    PM     <NA>      <NA>   <NA>    <NA>           2      m      0.0
# 15  <NA>     <NA>      <NA>   <NA>    <NA>           5      m      0.0
# 16     M     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 17  <NA>     <NA>      <NA>   <NA>    <NA>           7      m      0.0
# 18  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 19  <NA>     <NA>      <NA>   <NA>    <NA>           4      m      0.0
# 20    PM     <NA>      33.0   <NA>    <NA>        <NA>      m     33.0
# 21  <NA>     <NA>       9.0   <NA>    <NA>        <NA>      m      9.0
# 22    PM     <NA>       6.0   <NA>    <NA>        <NA>      m      6.0
# 23  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 24    PM     <NA>      19.2  131.7     D/6        <NA>      m    131.7
# 25  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 26    PM     <NA>      10.5   <NA>    <NA>        <NA>      m     57.5
# 27  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 28  <NA>     <NA>      <NA>   <NA>    <NA>          10      m      0.0
# 29     M     <NA>      <NA>   <NA>    <NA>           1      m     47.0
# 30  <NA>     <NA>      47.0   <NA>    <NA>        <NA>      m     47.0
# 31  <NA>     <NA>      <NA>   <NA>    <NA>          11      m      0.0
# 32  <NA>     <NA>      <NA>   <NA>    <NA>          11      m      0.0
# 33  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 34  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 35  <NA>     <NA>      <NA>   <NA>    <NA>           7      m      0.0
# 36  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 37  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 38  <NA>     <NA>      <NA>   <NA>    <NA>           1   c/30      0.0
# 39  <NA>     <NA>      55.0   <NA>    <NA>        <NA>      m     55.0
# 40     A     <NA>      <NA>   <NA>     D/5           1   <NA>     41.0
# 41    PM     <NA>      <NA>   41.0    D/23           1      m     41.0
# 42    PM     <NA>      41.0   <NA>    <NA>        <NA>      m     41.0
# 43    PM     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 44    PM     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 45    PM     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 46  <NA>     <NA>      <NA>   <NA>    <NA>          12      m      0.0
# 47  <NA>     <NA>      <NA>   <NA>    <NA>          12      m      0.0
# 48    DD     25.0      50.0  434.0     E/5        <NA>   <NA>   4947.3
# 49    PM     <NA>      <NA>   <NA>    D/15           2      m    715.8

# %%
df_gen.head(50)
# Out:
#     rownum  gen       Id  ParentId                              Name    cnv  \
# 0        1    0  6111685        -1                       Галюк Елена  > 500
# 1        2    1  6190205   6111685                     Галюк Дмитрий  > 500
# 2        3    2  6202838   6190205               Tabolich Anastasiya  > 500
# 3        4    2  6866923   6190205              Фалавандишвили Натия  > 500
# 4        5    3  6959087   6866923                  Мурванидзе Луиза  > 500
# 5        6    4  7309266   6959087                Murvanidze Violeta  135.5
# 6        7    3  7575828   6866923  Фалавандишвили Тинатин Тимуровна     35
# 7        8    2  7688719   6190205                     Konidala Anna  > 500
# 8        9    2  7791032   6190205              Shaposhnikov Mikhail    NaN
# 9       10    2  7805120   6190205            Галюк Елена Николаевна    NaN
# 10      11    2  7834868   6190205              Malyshava Katsiaryna     29
# 11      12    1  6190820   6111685                       Синица Тома  > 500
# 12      13    1  6203900   6111685                        Галюк Варя  > 500
# 13      14    2  6556807   6203900    Шидловская Анджела Григорьевна  > 500
# 14      15    3  6673758   6556807                    Вабищевич Анна  > 500
# 15      16    4  6684011   6673758                    Дедович Тамара  438.5
# 16      17    4  6782839   6673758       Вабищевич Владимир Петрович    221
# 17      18    4  6801396   6673758   Вабищевич Мирослав Владимирович  225.1
# 18      19    4  6842229   6673758     Будник Светлана Александровна  271.4
# 19      20    4  7254343   6673758               Федосенко Екатерина  133.5
# 20      21    3  6679651   6556807                   Нестер Христина  > 500
# 21      22    3  6702054   6556807                  Вечерова Наталья     99
# 22      23    3  6702224   6556807                        Нестер Яна  > 500
# 23      24    2  7187692   6203900   Коровкина Александра Михайловна  464.5
# 24      25    2  7310915   6203900                   Фролова Евгения  > 500
# 25      26    3  7322535   7310915                     Мадатова Дина   69.8
# 26      27    3  7338482   7310915                   Фролова Мелисса  > 500
# 27      28    4  7439339   7338482                    Грищенко Елена     94
# 28      29    4  7449946   7338482                  Назарова Наталия     90
# 29      30    4  7456980   7338482               Kosiakova Ekaterina  438.2
# 30      31    5  7843365   7456980        Шакирьянов Артур Рафикович    NaN
# 31      32    3  7436554   7310915     Терехина Екатерина Максимовна    133
# 32      33    4  7437494   7436554       Акудович Антонина Сергеевна     50
# 33      34    4  7526797   7436554               Mikhailova Nadezhda     71
# 34      35    3  7536391   7310915                   Minjaeva Olesya     24
# 35      36    3  7554677   7310915                   Makeenkova Anna     65
# 36      37    3  7577949   7310915                Astrouskaya Yuliya    168
# 37      38    3  7596790   7310915                     Frolov Dmitry  196.4
# 38      39    3  7833492   7310915                Lyashkevich Sofiya    NaN
# 39      40    3  7864524   7310915                    Rasulova Natia    NaN
# 40      41    1  6204299   6111685                        Галюк Надя  > 500
# 41      42    2  6217050   6204299                Шинкевич Валентина  > 500
# 42      43    3  6218172   6217050                   Шинкевич Андрей  > 500
# 43      44    4  6315386   6218172                   Михайлова Мария  > 500
# 44      45    4  6316880   6218172                      Шинкевич Яна  > 500
# 45      46    4  7049806   6218172         Воронович Юлия Валерьевна  > 500
# 46      47    2  6742267   6204299           Свирид Ирина Михайловна  362.8
# 47      48    2  6827084   6204299                  Станкевич Оксана  467.7
# 48      49    1  6300800   6111685         Баризоне Ольга Алексеевна  > 500
# 49      50    2  6361665   6300800                   Баризоне Серджо  > 500
#
#     Rank  Pending  Personal  Group maxrank  zeroMonths status  Overall
# 0      E     <NA>     100.0  230.0     E/1        <NA>   <NA>  12884.7
# 1      D     <NA>      <NA>   <NA>   SD/28           1      m      7.0
# 2     PM     <NA>      <NA>   <NA>    <NA>          12      m      0.0
# 3     PM     <NA>      <NA>    7.0    D/28           7      m      7.0
# 4     PM     <NA>       7.0   <NA>    <NA>        <NA>      m      7.0
# 5   <NA>     <NA>      <NA>   <NA>    <NA>           3      m      0.0
# 6   <NA>     <NA>      <NA>   <NA>    <NA>           7      m      0.0
# 7     PM     <NA>      <NA>   <NA>     D/4           1      m      0.0
# 8   <NA>     <NA>      <NA>   <NA>    <NA>           2   c/60      0.0
# 9   <NA>     <NA>      <NA>   <NA>    <NA>           1   c/49      0.0
# 10     M     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 11    PM     <NA>      21.5   21.5    D/69        <NA>      m     21.5
# 12     A     <NA>      43.5  102.5     D/3        <NA>   <NA>    234.2
# 13    PM     <NA>      11.0   <NA>    <NA>        <NA>      m     59.0
# 14    PM     <NA>      <NA>   <NA>    <NA>           2      m      0.0
# 15  <NA>     <NA>      <NA>   <NA>    <NA>           5      m      0.0
# 16     M     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 17  <NA>     <NA>      <NA>   <NA>    <NA>           7      m      0.0
# 18  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 19  <NA>     <NA>      <NA>   <NA>    <NA>           4      m      0.0
# 20    PM     <NA>      33.0   <NA>    <NA>        <NA>      m     33.0
# 21  <NA>     <NA>       9.0   <NA>    <NA>        <NA>      m      9.0
# 22    PM     <NA>       6.0   <NA>    <NA>        <NA>      m      6.0
# 23  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 24    PM     <NA>      19.2  131.7     D/6        <NA>      m    131.7
# 25  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 26    PM     <NA>      10.5   <NA>    <NA>        <NA>      m     57.5
# 27  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 28  <NA>     <NA>      <NA>   <NA>    <NA>          10      m      0.0
# 29     M     <NA>      <NA>   <NA>    <NA>           1      m     47.0
# 30  <NA>     <NA>      47.0   <NA>    <NA>        <NA>      m     47.0
# 31  <NA>     <NA>      <NA>   <NA>    <NA>          11      m      0.0
# 32  <NA>     <NA>      <NA>   <NA>    <NA>          11      m      0.0
# 33  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 34  <NA>     <NA>      <NA>   <NA>    <NA>           8      m      0.0
# 35  <NA>     <NA>      <NA>   <NA>    <NA>           7      m      0.0
# 36  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 37  <NA>     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 38  <NA>     <NA>      <NA>   <NA>    <NA>           1   c/30      0.0
# 39  <NA>     <NA>      55.0   <NA>    <NA>        <NA>      m     55.0
# 40     A     <NA>      <NA>   <NA>     D/5           1   <NA>     41.0
# 41    PM     <NA>      <NA>   41.0    D/23           1      m     41.0
# 42    PM     <NA>      41.0   <NA>    <NA>        <NA>      m     41.0
# 43    PM     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 44    PM     <NA>      <NA>   <NA>    <NA>           6      m      0.0
# 45    PM     <NA>      <NA>   <NA>    <NA>           1      m      0.0
# 46  <NA>     <NA>      <NA>   <NA>    <NA>          12      m      0.0
# 47  <NA>     <NA>      <NA>   <NA>    <NA>          12      m      0.0
# 48    DD     25.0      50.0  434.0     E/5        <NA>   <NA>   4947.3
# 49    PM     <NA>      <NA>   <NA>    D/15           2      m    715.8
