# %%
from pandas import *

df_raw: DataFrame = read_excel("data/4050120-FDRep-202305.xlsx", skiprows=6, na_values=[' '])

df_raw
# Out:
#                                                      № Уровень  Член клуба  \
# 0                                                    1     .0    4050120.0
# 1                                                    2     .1    4466027.0
# 2                                                    3     .2    4546363.0
# 3                                                    4     .3    4982008.0
# 4                                                    5     .3    5070606.0
# ..                                                 ...     ...         ...
# 412                отсутствие префикса — закрытый ранг     NaN         NaN
# 413                  НСО — накопительный сетевой объем     NaN         NaN
# 414                                нД — новый директор     NaN         NaN
# 415                            — потребитель в ранге Д     NaN         NaN
# 416  ПП (Премиум Потребитель) — это ранг, который п...     NaN         NaN
#
#                          Unnamed: 3 Ранг/нД     ЛО     НСО Max. 3Р    S
# 0        Евсигнеева Наталья Юрьевна      МЗ  100.0  3122.2    МЗ/0  NaN
# 1         Матат Сергей Владимирович    1оМС  127.0  2000.7     М/0  NaN
# 2          Матат Елена Владимировна     оИД  136.0   750.4    ЗД/0  NaN
# 3    Пухальская Алиса Станиславовна       Д  269.8   900.7   СД/17  NaN
# 4             Матат Семен Сергеевич       Д  469.0   923.0     Д/0  NaN
# ..                              ...     ...    ...     ...     ...  ...
# 412                             NaN     NaN    NaN     NaN     NaN  NaN
# 413                             NaN     NaN    NaN     NaN     NaN  NaN
# 414                             NaN     NaN    NaN     NaN     NaN  NaN
# 415                             NaN     NaN    NaN     NaN     NaN  NaN
# 416                             NaN     NaN    NaN     NaN     NaN  NaN
#
# [417 rows x 9 columns]

# %%
excel2Field = {}
excel2Field["#"] = "rownum"
excel2Field["Number of Generations"] = "gen"
excel2Field["Club Member (First name/Last name)"] = "Id"
excel2Field["Unnamed: 3"] = "Name"
excel2Field["CNV (Cumulated Network Volume)"] = "cnv"
excel2Field["Rank"] = "Rank"
excel2Field["P"] = "Pending"
excel2Field["PV (Personal Volume)"] = "Personal"
excel2Field["PVG"] = "Group"
excel2Field["MCR (Maximum Confirmed Rank)"] = "maxrank"
excel2Field["Number of months with zero Volume Points accrued"] = "zeroMonths"
excel2Field["Club Member Status"] = "status"

excel2Field["№"] = "rownum"
excel2Field["Уровень"] = "gen"
excel2Field["Член клуба"] = "Id"
excel2Field["НСО"] = "cnv"
excel2Field["Ранг/нД"] = "Rank"
excel2Field["P"] = "Pending"
excel2Field["ЛО"] = "Personal"
excel2Field["ЛГО"] = "Group"
excel2Field["Max. 3Р"] = "maxrank"
excel2Field["Number of months with zero Volume Points accrued"] = "zeroMonths"
excel2Field["S"] = "status"

df_renamed = df_raw.rename(columns=excel2Field)
df_renamed.head(30)
# Out:
#    rownum           gen         Id                              Name   Rank  \
# 0       1           .0   4050120.0        Евсигнеева Наталья Юрьевна     МЗ
# 1       2           .1   4466027.0         Матат Сергей Владимирович   1оМС
# 2       3           .2   4546363.0          Матат Елена Владимировна    оИД
# 3       4           .3   4982008.0    Пухальская Алиса Станиславовна      Д
# 4       5           .3   5070606.0             Матат Семен Сергеевич      Д
# 5       6           .3   7260026.0         Матат Севастьян Сергеевич      Д
# 6       7           .3   7374382.0              Buzhinskaya Svetlana      Д
# 7       8           .2   4552121.0          Кузняк Владимир Иванович     ЗД
# 8       9           .3   4552731.0  Тарасевич Николай Константинович  1о2МС
# 9      10           .4   4697386.0       Авраменко Дмитрий Сергеевич      Д
# 10     11           .4   4754900.0         Федчук Алексей Викторович     СД
# 11     12           .5   6187283.0                    Ткаченко Елена     СД
# 12     13           .6   6632080.0                Stefanik Yevgeniya     СД
# 13     14           .7   7232319.0                  Ponomareva Irina      Д
# 14     15           .4   4803921.0                      Snipas Olena      М
# 15     16           .5   4753988.0          Петренко Артур Антонович      Д
# 16     17           .5   4788370.0       Демир Екатерина Геннадиевна    оЗД
# 17     18           .6   7378709.0                  Каракаш Виктория     нД
# 18     19           .6   7380038.0       Хмельов Геннадій Васильович     нД
# 19     20           .5   4822177.0    Саманева Татьяна Александровна     ИД
# 20     21           .6   6680615.0                  Саманёва Людмила     СД
# 21     22           .7   6916763.0                 Шкуратова Евгения     СД
# 22     23           .8   6917470.0                     Постоева Анна     СД
# 23     24           .9   7355857.0           Любягина Ирина Петровна      Д
# 24     25           .6   6969651.0                     Heinz Andreas      Д
# 25     26           .6   7188445.0      Войтеховская Ната Валерьевна      Д
# 26     27           .5   6502352.0                        Brett Olga      Д
# 27     28           .5   6655592.0                    Snipas Evaldas      Д
# 28     29           .5   7150504.0             Александровна Людмила      Д
# 29     30           .5   7366631.0                Ponomarenko Larysa     нД
#
#     Personal     cnv maxrank status
# 0      100.0  3122.2    МЗ/0    NaN
# 1      127.0  2000.7     М/0    NaN
# 2      136.0   750.4    ЗД/0    NaN
# 3      269.8   900.7   СД/17    NaN
# 4      469.0   923.0     Д/0    NaN
# 5      250.0   879.1     Д/0    NaN
# 6      753.1   753.1     Д/0      п
# 7      113.1   500.0   БД/26    NaN
# 8      120.0  1426.4    МС/0    NaN
# 9       50.0   546.1   СД/16    NaN
# 10     351.0   500.0    СД/0    NaN
# 11     580.8   831.2    СД/0    NaN
# 12       NaN   572.3    СД/0    NaN
# 13     457.8   616.2     Д/0      п
# 14     115.0  2010.5     М/0    NaN
# 15      60.0   616.9    СД/6    NaN
# 16     339.0   750.9     Д/0    NaN
# 17     356.0   503.1     Д/0      п
# 18     446.0   750.0     Д/0      п
# 19     116.0  1442.6   БД/14    NaN
# 20     100.0   656.5    СД/0    NaN
# 21      68.1   612.5    ЗД/8    NaN
# 22     210.0   781.9    СД/0    NaN
# 23     115.2   540.0     Д/0      п
# 24     327.6   528.1     Д/0    NaN
# 25     417.6   575.6     Д/0    NaN
# 26     131.0   608.4   ИД/16    NaN
# 27      80.0   500.0     Д/0    NaN
# 28     269.0   506.0     Д/0      п
# 29     273.0   500.0     Д/0      п

# %%
df_neededColumns = df_renamed.drop(columns=["rownum", "cnv", "status", "maxrank", "Group"], errors="ignore")
df_neededColumns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df_neededColumns = df_renamed.drop(columns=["rownum", "cnv", "status", "maxrank", "Group"])
#       2 df_neededColumns
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Group'] not found in axis"

# %%
df_noNA = df_neededColumns.dropna(subset=['Id'])
df_noNA.head(20)
# Out:
#         gen         Id                              Name Rank  Pending  \
# 0       .0   6111685.0                       Галюк Елена    E      NaN
# 1       .1   6190205.0                     Галюк Дмитрий    D      NaN
# 2       .2   6202838.0               Tabolich Anastasiya   PM      NaN
# 3       .2   6866923.0              Фалавандишвили Натия   PM      NaN
# 4       .3   6959087.0                  Мурванидзе Луиза   PM      NaN
# 5       .4   7309266.0                Murvanidze Violeta  NaN      NaN
# 6       .3   7575828.0  Фалавандишвили Тинатин Тимуровна  NaN      NaN
# 7       .2   7688719.0                     Konidala Anna   PM      NaN
# 8       .2   7791032.0              Shaposhnikov Mikhail  NaN      NaN
# 9       .2   7805120.0            Галюк Елена Николаевна  NaN      NaN
# 10      .2   7834868.0              Malyshava Katsiaryna    M      NaN
# 11      .1   6190820.0                       Синица Тома   PM      NaN
# 12      .1   6203900.0                        Галюк Варя    A      NaN
# 13      .2   6556807.0    Шидловская Анджела Григорьевна   PM      NaN
# 14      .3   6673758.0                    Вабищевич Анна   PM      NaN
# 15      .4   6684011.0                    Дедович Тамара  NaN      NaN
# 16      .4   6782839.0       Вабищевич Владимир Петрович    M      NaN
# 17      .4   6801396.0   Вабищевич Мирослав Владимирович  NaN      NaN
# 18      .4   6842229.0     Будник Светлана Александровна  NaN      NaN
# 19      .4   7254343.0               Федосенко Екатерина  NaN      NaN
#
#     Personal  zeroMonths
# 0      100.0         NaN
# 1        NaN         1.0
# 2        NaN        12.0
# 3        NaN         7.0
# 4        7.0         NaN
# 5        NaN         3.0
# 6        NaN         7.0
# 7        NaN         1.0
# 8        NaN         2.0
# 9        NaN         1.0
# 10       NaN         1.0
# 11      21.5         NaN
# 12      43.5         NaN
# 13      11.0         NaN
# 14       NaN         2.0
# 15       NaN         5.0
# 16       NaN         1.0
# 17       NaN         7.0
# 18       NaN         6.0
# 19       NaN         4.0

# %%
df_recast = df_noNA.convert_dtypes(convert_floating=True, convert_integer=True)
df_recast["Personal"].astype(float)
df_recast["Id"].astype(int)
df_recast
# Out:
#         gen       Id                  Name  Rank  Pending  Personal  \
# 0       .0   6111685           Галюк Елена     E     <NA>     100.0
# 1       .1   6190205         Галюк Дмитрий     D     <NA>      <NA>
# 2       .2   6202838   Tabolich Anastasiya    PM     <NA>      <NA>
# 3       .2   6866923  Фалавандишвили Натия    PM     <NA>      <NA>
# 4       .3   6959087      Мурванидзе Луиза    PM     <NA>       7.0
# ..      ...      ...                   ...   ...      ...       ...
# 723     .1   7625037       Зоидзе Светлана  <NA>     <NA>      <NA>
# 724     .1   7634313       Rodionova Elena  <NA>     <NA>      <NA>
# 725     .1   7659464        Каитамба Раули     M     <NA>      <NA>
# 726     .1   7742962         Павлова Ирина    PM     <NA>      <NA>
# 727     .1   7821743       Lohvynenko Olha  <NA>     <NA>      68.0
#
#      zeroMonths
# 0          <NA>
# 1             1
# 2            12
# 3             7
# 4          <NA>
# ..          ...
# 723           4
# 724           2
# 725           1
# 726           2
# 727        <NA>
#
# [728 rows x 7 columns]

# %%
df_gen = df_recast
df_gen.gen = df_gen.gen.apply(lambda x: int(str(x).split(".")[-1]) )
df_gen
# Out:
#      gen       Id                  Name  Rank  Pending  Personal  zeroMonths
# 0      0  6111685           Галюк Елена     E     <NA>     100.0        <NA>
# 1      1  6190205         Галюк Дмитрий     D     <NA>      <NA>           1
# 2      2  6202838   Tabolich Anastasiya    PM     <NA>      <NA>          12
# 3      2  6866923  Фалавандишвили Натия    PM     <NA>      <NA>           7
# 4      3  6959087      Мурванидзе Луиза    PM     <NA>       7.0        <NA>
# ..   ...      ...                   ...   ...      ...       ...         ...
# 723    1  7625037       Зоидзе Светлана  <NA>     <NA>      <NA>           4
# 724    1  7634313       Rodionova Elena  <NA>     <NA>      <NA>           2
# 725    1  7659464        Каитамба Раули     M     <NA>      <NA>           1
# 726    1  7742962         Павлова Ирина    PM     <NA>      <NA>           2
# 727    1  7821743       Lohvynenko Olha  <NA>     <NA>      68.0        <NA>
#
# [728 rows x 7 columns]

# %%
levelId = {}
def id_gen_2_parent(id, gen) -> int:
    levelId[gen] = id
    return levelId[gen-1] if gen > 0 else -1

if "ParentId" not in df_gen.columns:
    df_gen.insert(loc=3, column="ParentId", value=df_gen.apply(lambda x: id_gen_2_parent(x.Id, x.gen), axis=1))
    df_gen.ParentId = df_gen.ParentId.astype(int)

df_gen
# Out:
#      gen       Id                  Name  ParentId  Rank  Pending  Personal  \
# 0      0  6111685           Галюк Елена        -1     E     <NA>     100.0
# 1      1  6190205         Галюк Дмитрий   6111685     D     <NA>      <NA>
# 2      2  6202838   Tabolich Anastasiya   6190205    PM     <NA>      <NA>
# 3      2  6866923  Фалавандишвили Натия   6190205    PM     <NA>      <NA>
# 4      3  6959087      Мурванидзе Луиза   6866923    PM     <NA>       7.0
# ..   ...      ...                   ...       ...   ...      ...       ...
# 723    1  7625037       Зоидзе Светлана   6111685  <NA>     <NA>      <NA>
# 724    1  7634313       Rodionova Elena   6111685  <NA>     <NA>      <NA>
# 725    1  7659464        Каитамба Раули   6111685     M     <NA>      <NA>
# 726    1  7742962         Павлова Ирина   6111685    PM     <NA>      <NA>
# 727    1  7821743       Lohvynenko Olha   6111685  <NA>     <NA>      68.0
#
#      zeroMonths
# 0          <NA>
# 1             1
# 2            12
# 3             7
# 4          <NA>
# ..          ...
# 723           4
# 724           2
# 725           1
# 726           2
# 727        <NA>
#
# [728 rows x 8 columns]

# %%
members = {}
parents = {}

def calculate_overallstructure_total(id):
    member = members[id]
    member["Overall"] += member["Personal"] or 0
    if id in parents:
        children = [c for c in members.values() if c["ParentId"] == member["Id"]]
        for c in children:
            member["Overall"] += calculate_overallstructure_total(c["Id"])
    return member["Overall"]

df_gen["Overall"] = 0
d = df_gen.to_dict(orient="index")
members = {r["Id"] : r for r in d.values()}
parents = {r["ParentId"] : r["Id"] for r in d.values()}
calculate_overallstructure_total(parents[-1])
memberOverall = {x["Id"]: x["Overall"] for x in members.values()}
df_gen["Overall"] = df_gen["Id"].map(memberOverall)

# %%
df_gen.head(50)
# Out:
#     gen       Id                              Name  ParentId  Rank  Pending  \
# 0     0  6111685                       Галюк Елена        -1     E     <NA>
# 1     1  6190205                     Галюк Дмитрий   6111685     D     <NA>
# 2     2  6202838               Tabolich Anastasiya   6190205    PM     <NA>
# 3     2  6866923              Фалавандишвили Натия   6190205    PM     <NA>
# 4     3  6959087                  Мурванидзе Луиза   6866923    PM     <NA>
# 5     4  7309266                Murvanidze Violeta   6959087  <NA>     <NA>
# 6     3  7575828  Фалавандишвили Тинатин Тимуровна   6866923  <NA>     <NA>
# 7     2  7688719                     Konidala Anna   6190205    PM     <NA>
# 8     2  7791032              Shaposhnikov Mikhail   6190205  <NA>     <NA>
# 9     2  7805120            Галюк Елена Николаевна   6190205  <NA>     <NA>
# 10    2  7834868              Malyshava Katsiaryna   6190205     M     <NA>
# 11    1  6190820                       Синица Тома   6111685    PM     <NA>
# 12    1  6203900                        Галюк Варя   6111685     A     <NA>
# 13    2  6556807    Шидловская Анджела Григорьевна   6203900    PM     <NA>
# 14    3  6673758                    Вабищевич Анна   6556807    PM     <NA>
# 15    4  6684011                    Дедович Тамара   6673758  <NA>     <NA>
# 16    4  6782839       Вабищевич Владимир Петрович   6673758     M     <NA>
# 17    4  6801396   Вабищевич Мирослав Владимирович   6673758  <NA>     <NA>
# 18    4  6842229     Будник Светлана Александровна   6673758  <NA>     <NA>
# 19    4  7254343               Федосенко Екатерина   6673758  <NA>     <NA>
# 20    3  6679651                   Нестер Христина   6556807    PM     <NA>
# 21    3  6702054                  Вечерова Наталья   6556807  <NA>     <NA>
# 22    3  6702224                        Нестер Яна   6556807    PM     <NA>
# 23    2  7187692   Коровкина Александра Михайловна   6203900  <NA>     <NA>
# 24    2  7310915                   Фролова Евгения   6203900    PM     <NA>
# 25    3  7322535                     Мадатова Дина   7310915  <NA>     <NA>
# 26    3  7338482                   Фролова Мелисса   7310915    PM     <NA>
# 27    4  7439339                    Грищенко Елена   7338482  <NA>     <NA>
# 28    4  7449946                  Назарова Наталия   7338482  <NA>     <NA>
# 29    4  7456980               Kosiakova Ekaterina   7338482     M     <NA>
# 30    5  7843365        Шакирьянов Артур Рафикович   7456980  <NA>     <NA>
# 31    3  7436554     Терехина Екатерина Максимовна   7310915  <NA>     <NA>
# 32    4  7437494       Акудович Антонина Сергеевна   7436554  <NA>     <NA>
# 33    4  7526797               Mikhailova Nadezhda   7436554  <NA>     <NA>
# 34    3  7536391                   Minjaeva Olesya   7310915  <NA>     <NA>
# 35    3  7554677                   Makeenkova Anna   7310915  <NA>     <NA>
# 36    3  7577949                Astrouskaya Yuliya   7310915  <NA>     <NA>
# 37    3  7596790                     Frolov Dmitry   7310915  <NA>     <NA>
# 38    3  7833492                Lyashkevich Sofiya   7310915  <NA>     <NA>
# 39    3  7864524                    Rasulova Natia   7310915  <NA>     <NA>
# 40    1  6204299                        Галюк Надя   6111685     A     <NA>
# 41    2  6217050                Шинкевич Валентина   6204299    PM     <NA>
# 42    3  6218172                   Шинкевич Андрей   6217050    PM     <NA>
# 43    4  6315386                   Михайлова Мария   6218172    PM     <NA>
# 44    4  6316880                      Шинкевич Яна   6218172    PM     <NA>
# 45    4  7049806         Воронович Юлия Валерьевна   6218172    PM     <NA>
# 46    2  6742267           Свирид Ирина Михайловна   6204299  <NA>     <NA>
# 47    2  6827084                  Станкевич Оксана   6204299  <NA>     <NA>
# 48    1  6300800         Баризоне Ольга Алексеевна   6111685    DD     25.0
# 49    2  6361665                   Баризоне Серджо   6300800    PM     <NA>
#
#     Personal  zeroMonths  Overall
# 0      100.0        <NA>  12884.7
# 1       <NA>           1      7.0
# 2       <NA>          12      0.0
# 3       <NA>           7      7.0
# 4        7.0        <NA>      7.0
# 5       <NA>           3      0.0
# 6       <NA>           7      0.0
# 7       <NA>           1      0.0
# 8       <NA>           2      0.0
# 9       <NA>           1      0.0
# 10      <NA>           1      0.0
# 11      21.5        <NA>     21.5
# 12      43.5        <NA>    234.2
# 13      11.0        <NA>     59.0
# 14      <NA>           2      0.0
# 15      <NA>           5      0.0
# 16      <NA>           1      0.0
# 17      <NA>           7      0.0
# 18      <NA>           6      0.0
# 19      <NA>           4      0.0
# 20      33.0        <NA>     33.0
# 21       9.0        <NA>      9.0
# 22       6.0        <NA>      6.0
# 23      <NA>           6      0.0
# 24      19.2        <NA>    131.7
# 25      <NA>           8      0.0
# 26      10.5        <NA>     57.5
# 27      <NA>           8      0.0
# 28      <NA>          10      0.0
# 29      <NA>           1     47.0
# 30      47.0        <NA>     47.0
# 31      <NA>          11      0.0
# 32      <NA>          11      0.0
# 33      <NA>           8      0.0
# 34      <NA>           8      0.0
# 35      <NA>           7      0.0
# 36      <NA>           6      0.0
# 37      <NA>           6      0.0
# 38      <NA>           1      0.0
# 39      55.0        <NA>     55.0
# 40      <NA>           1     41.0
# 41      <NA>           1     41.0
# 42      41.0        <NA>     41.0
# 43      <NA>           1      0.0
# 44      <NA>           6      0.0
# 45      <NA>           1      0.0
# 46      <NA>          12      0.0
# 47      <NA>          12      0.0
# 48      50.0        <NA>   4947.3
# 49      <NA>           2    715.8
